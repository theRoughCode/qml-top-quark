# %% [markdown]
# <a href="https://colab.research.google.com/github/theRoughCode/qml-top-quark/blob/notebook/top_quark_reuploading_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data reuploading
#
# In this sample notebook, we apply the data reuploading circuit proposed by [Pérez-Salinas et al. (2019)](https://arxiv.org/abs/1907.02085) to the 4 top quark dataset.
#
# <p align="center">
#   <img src="https://pennylane.ai/qml/_images/universal_dnn.png" width="50%" />
# </p>
#
# [Image source](https://pennylane.ai/qml/demos/tutorial_data_reuploading_classifier.html)
#
# ## Background
# The Standard Model predicts the production of 4 top quarks from proton-proton interactions at the centre-of-mass energy of √s = 13 TeV. Our goal is to apply using the data reuploading variational quantum circuit to identify the 4 top quark signal against competing tt ̄ + jets background.

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q tensorflow==2.4.1
# !pip install -q -U tensorflow-quantum

# %%
import tensorflow as tf
import tensorflow_quantum as tfq

from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import os
import cirq
import math
import sympy
import collections
import numpy as np
import pandas as pd

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit

# %% [markdown]
# ## Download dataset
#
# We will be using the 4 top quark dataset produced using Monte-Carlo simulations. For this sample notebook, we will only be using 5000 samples.
#
# Each sample has 76 features and the last column represents its type (signal=1 or background=0).

# %%
df = pd.read_pickle("https://drive.google.com/uc?export=download&id=18VGtTeI4EEki5l8dz1Bloyz_toDPnTGl")
df
# Out:
#          b'AK4HTpMETpLepPt'  ...  b'type'
# 1177704          682.735352  ...      0.0
# 1277853         1000.195374  ...      0.0
# 145952           738.931213  ...      1.0
# 53830           1480.729614  ...      1.0
# 1006402         1074.837036  ...      0.0
# ...                     ...  ...      ...
# 1465193         1617.045898  ...      0.0
# 367400           651.665100  ...      0.0
# 1567299          909.042419  ...      0.0
# 9634             953.733887  ...      1.0
# 125042           866.174377  ...      1.0
#
# [5000 rows x 77 columns]

# %% [markdown]
# ### Variable importance ranking
# In previous work, Narain et al. ranked the 76 variables according to their relative importance to the performance of a DNN (Dense Neural Network).
#
# In this notebook, we will pick the top 3 variables and use them in our classification task.

# %%
NUM_VARS = 3

nJ4_2017_top_30_variables = pd.read_csv("https://drive.google.com/uc?export=download&id=1d8FgsKW1HpCEloqvxmIqHRtBUwBpjCV5")
nJ4_2017_top_30_variables = nJ4_2017_top_30_variables.columns.values.tolist()
top_n_variables = nJ4_2017_top_30_variables[:NUM_VARS]
# Encode strings into bytes to be compatible with df column names
top_n_variables = [str.encode(s) for s in top_n_variables]
top_n_variables
# Out:
# [b'thirdcsvb_bb', b'MT_lepMet', b'fourthcsvb_bb']

# %%
# Filter out top NUM_VARS columns and convert to numpy array
ds_x = df[top_n_variables].to_numpy()
ds_y = df[b"type"].to_numpy()

# %% [markdown]
# ## Preprocessing
#
# The data values have a wide range. Scaling and normalizing the input data can aid in training performance and stability.
#
# Let's see the range of data values we're dealing with.

# %%
np.min(ds_x), np.max(ds_x)
# Out:
# (-2.0, 732.0361938476562)

# %% [markdown]
# To normalize the data, we pass them through 2 preprocessors:
# 1. StandardScaler: standardize features by removing the mean and scaling to unit variance
# 2. MinMaxScaler: scale and translate data to be in the range `[-1, 1]`

# %%
preprocessors = [StandardScaler(), MinMaxScaler((-1, 1))]

for preprocessor in preprocessors:
  ds_x = preprocessor.fit_transform(ds_x)

# %% [markdown]
# Finally, we split the dataset up into training, test, and validation sets in the ratio 80/10/10, respectively.

# %%
x_train, x_test, y_train, y_test = train_test_split(ds_x, ds_y, test_size=0.1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=len(x_test))

# %% [markdown]
# ## Building our Quantum model
# In this section, we build our data reuploading model using Tensorflow Quantum.
#
# First, let's define a helper function that performs an arbitrary single-qubit rotation on a given qubit. In the Tensorflow Quantum framework, we construct quantum circuits using [Cirq](https://quantumai.google/cirq).
#
# This function takes in a qubit and 3 angles, and performs an RX, RY, and RZ rotation.

# %%
def one_qubit_unitary(bit, inputs):
    """Make a Cirq circuit enacting a rotation of the bloch sphere about the X,
    Y and Z axis, that depends on the values in `inputs`.
    Bit: 1
    Inputs: 3
    """
    return cirq.Circuit(
        cirq.X(bit) ** inputs[0],
        cirq.Y(bit) ** inputs[1],
        cirq.Z(bit) ** inputs[2],
    )

# %% [markdown]
# Now, we define the data reuploading circuit as a Tensorflow `Layer`:

# %%
class ReuploadingCircuit(tf.keras.layers.Layer):
  def __init__(self, input_dims, num_qubits, num_layers, name='re-uploading_circuit'):
    super(ReuploadingCircuit, self).__init__()
    self.num_qubits = num_qubits
    self.num_layers = num_layers

    # Encode inputs in groups of 3
    self.num_encoding_blocks = math.ceil(input_dims / 3) 
    self.num_params = self.num_encoding_blocks * 3

    weights_init = tf.random_uniform_initializer(minval=-1.0, maxval=1.0)
    self.num_weights = self.num_qubits * self.num_layers * 3
    self.thetas = tf.Variable(
        initial_value=weights_init(shape=(1, self.num_weights), dtype='float32'),
        trainable=True,
        name='thetas')
    self.empty_circuit = tfq.convert_to_tensor([cirq.Circuit()])

    self.pqc = self.build_model()
    
  def build_model(self):
    qubits = cirq.GridQubit.rect(1, self.num_qubits)
    readouts = [cirq.Z(qubits[-1])]

    # Sympy symbols for encoding inputs
    encoding_params = sympy.symbols(f'x_0:{self.num_encoding_blocks * 3}')
    encoding_params = np.asarray(encoding_params).reshape((self.num_encoding_blocks, 3))

    # Sympy symbols for trainable parameters
    trainable_params = sympy.symbols(f'θ_0:{self.num_weights}')
    trainable_params = np.asarray(trainable_params).reshape((self.num_layers, self.num_qubits, 3))

    # Define explicit symbol order to follow the alphabetical order of their symbol names,
    # as processed by the ControlledPQC.
    symbols = [str(symb) for symb in list(encoding_params.flat) + list(trainable_params.flat)]
    self.indices = tf.constant([sorted(symbols).index(a) for a in symbols])

    # Create circuit
    circuit = cirq.Circuit()
    for l in range(self.num_layers):
      # Encoding layer
      for q in qubits:
        circuit += cirq.Circuit(one_qubit_unitary(q, encoding_params[b]) for b in range(self.num_encoding_blocks))

      # Variational layer
      circuit += cirq.Circuit(one_qubit_unitary(q, trainable_params[l, i]) for i, q in enumerate(qubits))

      # Entangling layer
      if self.num_qubits > 1:
        if l < self.num_layers - 1:
          # entangle qubits if not last layer
          circuit += [cirq.CZ(q0, q1) for q0, q1 in zip(qubits, qubits[1:])]

    print(circuit)

    pqc = tfq.layers.ControlledPQC(circuit, readouts)

    return pqc

  def call(self, inputs):
    batch_size = tf.shape(inputs)[0]

    # Duplicate thetas across batch
    thetas = tf.tile(self.thetas, multiples=[batch_size, 1], name='tile_weights')

    # Pad tensors if necessary
    num_padding = self.num_params - inputs.shape[1]
    if num_padding != 0:
      inputs = tf.pad(inputs, tf.constant([[0, 0,], [0, num_padding]]), name='pad_inputs')

    # Flatten inputs
    flattened = tf.keras.layers.Flatten(name='flatten')(inputs)

    circuits = tf.repeat(self.empty_circuit, repeats=batch_size, name='tile_circuits')
    model_params = tf.concat([flattened, thetas], axis=-1, name='concat_model_params')
    model_params = tf.gather(model_params, self.indices, axis=-1, name='permute_model_params')

    return self.pqc([circuits, model_params])

# %% [markdown]
# Finally, we wrap our reuploading layer into a Tensorflow `Model`. Note that the `ReuploadingCircuit` layer outputs values in the range `[-1, 1]`, corresponding to the expectation values of the Pauli Z measurement. We allow optionally adding a classical classification head.

# %%
def build_reuploading_model(num_qubits, num_layers, use_classical=False):
  inputs = tf.keras.Input(shape=(NUM_VARS,), dtype=tf.dtypes.float32)
  x = ReuploadingCircuit(NUM_VARS, num_qubits, num_layers)(inputs)

  if use_classical:
    out = tf.keras.layers.Dense(1, activation='sigmoid')(x)
  else:
    out = (x + 1.) / 2.

  model = tf.keras.Model(inputs=inputs, outputs=out)

  return model

# %% [markdown]
# Let's construct a reuploading circuit of a single qubit and 6 layers, with a classical classification head.

# %%
BATCH_SIZE = 64

model = build_reuploading_model(1, 6, True)
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-3), metrics=['binary_accuracy', tf.keras.metrics.AUC(name='auc')])
model.summary()
# Out:
# (0, 0): ───X^x_0───Y^x_1───Z^x_2───X^(θ_0)───Y^(θ_1)───Z^(θ_2)───X^x_0───Y^x_1───Z^x_2───X^(θ_3)───Y^(θ_4)───Z^(θ_5)───X^x_0───Y^x_1───Z^x_2───X^(θ_6)───Y^(θ_7)───Z^(θ_8)───X^x_0───Y^x_1───Z^x_2───X^(θ_9)───Y^(θ_10)───Z^(θ_11)───X^x_0───Y^x_1───Z^x_2───X^(θ_12)───Y^(θ_13)───Z^(θ_14)───X^x_0───Y^x_1───Z^x_2───X^(θ_15)───Y^(θ_16)───Z^(θ_17)───
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# reuploading_circuit (Reuploa (None, 1)                 18
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training
#
# Before training our model, we convert our datasets into Tensorflow `Dataset`s and batch them.

# %%
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(BATCH_SIZE, drop_remainder=True)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH_SIZE, drop_remainder=True)
val_ds = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# Let's start training!

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)

history = model.fit(train_ds,
        batch_size=BATCH_SIZE,
        epochs=20,
        verbose=1,
        validation_data=val_ds,
        callbacks=[callback])
# Out:
# Epoch 1/20
# 62/62 [==============================] - 8s 107ms/step - loss: 0.8231 - binary_accuracy: 0.4618 - auc: 0.4439 - val_loss: 0.7498 - val_binary_accuracy: 0.5290 - val_auc: 0.5265
# Epoch 2/20
# 62/62 [==============================] - 7s 108ms/step - loss: 0.7230 - binary_accuracy: 0.5579 - auc: 0.5691 - val_loss: 0.6689 - val_binary_accuracy: 0.6161 - val_auc: 0.6484
# Epoch 3/20
# 62/62 [==============================] - 7s 112ms/step - loss: 0.6747 - binary_accuracy: 0.6106 - auc: 0.6416 - val_loss: 0.6493 - val_binary_accuracy: 0.6384 - val_auc: 0.6817
# Epoch 4/20
# 62/62 [==============================] - 7s 109ms/step - loss: 0.6597 - binary_accuracy: 0.6145 - auc: 0.6637 - val_loss: 0.6350 - val_binary_accuracy: 0.6562 - val_auc: 0.7015
# Epoch 5/20
# 62/62 [==============================] - 7s 111ms/step - loss: 0.6459 - binary_accuracy: 0.6315 - auc: 0.6827 - val_loss: 0.6166 - val_binary_accuracy: 0.6719 - val_auc: 0.7266
# Epoch 6/20
# 62/62 [==============================] - 7s 110ms/step - loss: 0.6280 - binary_accuracy: 0.6427 - auc: 0.7071 - val_loss: 0.5946 - val_binary_accuracy: 0.6830 - val_auc: 0.7549
# Epoch 7/20
# 62/62 [==============================] - 7s 111ms/step - loss: 0.6090 - binary_accuracy: 0.6704 - auc: 0.7345 - val_loss: 0.5766 - val_binary_accuracy: 0.7188 - val_auc: 0.7785
# Epoch 8/20
# 62/62 [==============================] - 7s 110ms/step - loss: 0.5957 - binary_accuracy: 0.6921 - auc: 0.7510 - val_loss: 0.5646 - val_binary_accuracy: 0.7277 - val_auc: 0.7929
# Epoch 9/20
# 62/62 [==============================] - 7s 112ms/step - loss: 0.5880 - binary_accuracy: 0.7053 - auc: 0.7588 - val_loss: 0.5569 - val_binary_accuracy: 0.7299 - val_auc: 0.8022
# Epoch 10/20
# 62/62 [==============================] - 7s 112ms/step - loss: 0.5830 - binary_accuracy: 0.7108 - auc: 0.7638 - val_loss: 0.5517 - val_binary_accuracy: 0.7433 - val_auc: 0.8075
# Epoch 11/20
# 62/62 [==============================] - 7s 118ms/step - loss: 0.5795 - binary_accuracy: 0.7117 - auc: 0.7673 - val_loss: 0.5480 - val_binary_accuracy: 0.7522 - val_auc: 0.8110
# Epoch 12/20
# 62/62 [==============================] - 7s 115ms/step - loss: 0.5765 - binary_accuracy: 0.7146 - auc: 0.7704 - val_loss: 0.5452 - val_binary_accuracy: 0.7567 - val_auc: 0.8121
# Epoch 13/20
# 62/62 [==============================] - 7s 115ms/step - loss: 0.5739 - binary_accuracy: 0.7125 - auc: 0.7729 - val_loss: 0.5430 - val_binary_accuracy: 0.7589 - val_auc: 0.8128
# Epoch 14/20
# 62/62 [==============================] - 7s 113ms/step - loss: 0.5716 - binary_accuracy: 0.7163 - auc: 0.7757 - val_loss: 0.5412 - val_binary_accuracy: 0.7567 - val_auc: 0.8141
# Epoch 15/20
# 62/62 [==============================] - 7s 116ms/step - loss: 0.5695 - binary_accuracy: 0.7193 - auc: 0.7780 - val_loss: 0.5397 - val_binary_accuracy: 0.7567 - val_auc: 0.8152
# Epoch 16/20
# 62/62 [==============================] - 7s 116ms/step - loss: 0.5676 - binary_accuracy: 0.7202 - auc: 0.7801 - val_loss: 0.5383 - val_binary_accuracy: 0.7567 - val_auc: 0.8155
# Epoch 17/20
# 62/62 [==============================] - 7s 113ms/step - loss: 0.5660 - binary_accuracy: 0.7208 - auc: 0.7819 - val_loss: 0.5372 - val_binary_accuracy: 0.7545 - val_auc: 0.8156
# Epoch 18/20
# 62/62 [==============================] - 7s 115ms/step - loss: 0.5646 - binary_accuracy: 0.7205 - auc: 0.7837 - val_loss: 0.5362 - val_binary_accuracy: 0.7567 - val_auc: 0.8167
# Epoch 19/20
# 62/62 [==============================] - 7s 117ms/step - loss: 0.5634 - binary_accuracy: 0.7200 - auc: 0.7845 - val_loss: 0.5354 - val_binary_accuracy: 0.7545 - val_auc: 0.8160
# Epoch 20/20
# 62/62 [==============================] - 7s 118ms/step - loss: 0.5623 - binary_accuracy: 0.7216 - auc: 0.7857 - val_loss: 0.5347 - val_binary_accuracy: 0.7545 - val_auc: 0.8163

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# Let's see how our trained model does on our test dataset:

# %%
y_score = model.predict(test_ds)
# We need to trim `y_test`z to account for dropped samples when batching `test_ds`
y_true = y_test[:len(y_score)]

# Plot ROC curve
fpr, tpr, _ = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

plt.plot(tpr, 1 - fpr, label="ROC, {} variables, AUC={:.4f}".format(NUM_VARS, roc_auc), linewidth=2)
plt.xlabel("Signal Efficiency", fontsize=18, fontweight='bold')
plt.ylabel("Background Rejection", fontsize=18, fontweight='bold')
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.grid(color='gray', linestyle='--', linewidth=1) 
plt.plot([0, 1], [1, 0], linestyle='--', color='black', label='Luck, AUC= 0.5')
plt.legend(loc='best',prop={'size': 8})

# %% [markdown]
# ## Varying number of qubits and layers
# Let's see how our model performs as we vary the number of qubits and layers.

# %%
models = [
  build_reuploading_model(1, 6, BATCH_SIZE),
  build_reuploading_model(2, 3, BATCH_SIZE),
  build_reuploading_model(3, 2, BATCH_SIZE),
  build_reuploading_model(6, 1, BATCH_SIZE),
]
for model in models:
  model.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-3), metrics=['binary_accuracy', tf.keras.metrics.AUC(name='auc')])
# Out:
# (0, 0): ───X^x_0───Y^x_1───Z^x_2───X^(θ_0)───Y^(θ_1)───Z^(θ_2)───X^x_0───Y^x_1───Z^x_2───X^(θ_3)───Y^(θ_4)───Z^(θ_5)───X^x_0───Y^x_1───Z^x_2───X^(θ_6)───Y^(θ_7)───Z^(θ_8)───X^x_0───Y^x_1───Z^x_2───X^(θ_9)───Y^(θ_10)───Z^(θ_11)───X^x_0───Y^x_1───Z^x_2───X^(θ_12)───Y^(θ_13)───Z^(θ_14)───X^x_0───Y^x_1───Z^x_2───X^(θ_15)───Y^(θ_16)───Z^(θ_17)───
# (0, 0): ───X^x_0───Y^x_1───Z^x_2───────────────────────────X^(θ_0)───Y^(θ_1)───Z^(θ_2)─────────────────────────────────@───X^x_0───Y^x_1───Z^x_2───────────────────────────X^(θ_6)───Y^(θ_7)───Z^(θ_8)───────────────────────────────────@───X^x_0───Y^x_1───Z^x_2───────────────────────────X^(θ_12)───Y^(θ_13)───Z^(θ_14)────────────────────────────────────
#                                                                                                                        │                                                                                                                 │
# (0, 1): ───────────────────────────X^x_0───Y^x_1───Z^x_2─────────────────────────────────X^(θ_3)───Y^(θ_4)───Z^(θ_5)───@───────────────────────────X^x_0───Y^x_1───Z^x_2─────────────────────────────────X^(θ_9)───Y^(θ_10)───Z^(θ_11)───@───────────────────────────X^x_0───Y^x_1───Z^x_2────────────────────────────────────X^(θ_15)───Y^(θ_16)───Z^(θ_17)───
# (0, 0): ───X^x_0───Y^x_1───Z^x_2───────────────────────────────────────────────────X^(θ_0)───Y^(θ_1)───Z^(θ_2)─────────────────────────────────@─────────────────────────────────X^x_0───Y^x_1───Z^x_2───────────────────────────────────────────────────X^(θ_9)───Y^(θ_10)───Z^(θ_11)─────────────────────────────────────────────────────────────────────
#                                                                                                                                                │
# (0, 1): ───────────────────────────X^x_0───Y^x_1───Z^x_2─────────────────────────────────────────────────────────X^(θ_3)───Y^(θ_4)───Z^(θ_5)───@─────────────────────────────@───────────────────────────X^x_0───Y^x_1───Z^x_2───────────────────────────────────────────────────────────X^(θ_12)───Y^(θ_13)───Z^(θ_14)────────────────────────────────────
#                                                                                                                                                                              │
# (0, 2): ───────────────────────────────────────────────────X^x_0───Y^x_1───Z^x_2───────────────────────────────────────────────────────────────X^(θ_6)───Y^(θ_7)───Z^(θ_8)───@───────────────────────────────────────────────────X^x_0───Y^x_1───Z^x_2────────────────────────────────────────────────────────────────────X^(θ_15)───Y^(θ_16)───Z^(θ_17)───
# (0, 0): ───X^x_0───Y^x_1───Z^x_2───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X^(θ_0)───Y^(θ_1)───Z^(θ_2)─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# (0, 1): ───────────────────────────X^x_0───Y^x_1───Z^x_2─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X^(θ_3)───Y^(θ_4)───Z^(θ_5)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# (0, 2): ───────────────────────────────────────────────────X^x_0───Y^x_1───Z^x_2───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X^(θ_6)───Y^(θ_7)───Z^(θ_8)─────────────────────────────────────────────────────────────────────────────────────────────────────
#
# (0, 3): ───────────────────────────────────────────────────────────────────────────X^x_0───Y^x_1───Z^x_2─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X^(θ_9)───Y^(θ_10)───Z^(θ_11)─────────────────────────────────────────────────────────────────────
#
# (0, 4): ───────────────────────────────────────────────────────────────────────────────────────────────────X^x_0───Y^x_1───Z^x_2─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X^(θ_12)───Y^(θ_13)───Z^(θ_14)────────────────────────────────────
#
# (0, 5): ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X^x_0───Y^x_1───Z^x_2──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X^(θ_15)───Y^(θ_16)───Z^(θ_17)───

# %% [markdown]
# These parameters were chosen specifically so that the number of trainable parameters in the models are the same. We see below that they all have 20 parameters.

# %%
for model in models:
  print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# reuploading_circuit_1 (Reupl (None, 1)                 18
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# reuploading_circuit_2 (Reupl (None, 1)                 18
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# reuploading_circuit_3 (Reupl (None, 1)                 18
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# reuploading_circuit_4 (Reupl (None, 1)                 18
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Classical Neural Network
# Let's add in a classical neural network (of similar size) to see how our quantum models compare with it.

# %%
def create_classical_model():
    inputs = tf.keras.Input(shape=(NUM_VARS,), dtype=tf.dtypes.float32)
    x = tf.keras.layers.Dense(4, activation='relu')(inputs)
    out = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    model = tf.keras.Model(inputs=inputs, outputs=out)

    return model


model = create_classical_model()
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-3), metrics=['binary_accuracy', tf.keras.metrics.AUC(name='auc')])

model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 16
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %%
models.append(model)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)

# Train the models
for i, model in enumerate(models):
  model.fit(train_ds,
        batch_size=BATCH_SIZE,
        epochs=20,
        verbose=1,
        validation_data=val_ds,
        callbacks=[callback])
# Out:
# Epoch 1/20
# 62/62 [==============================] - 9s 126ms/step - loss: 0.6893 - binary_accuracy: 0.5865 - auc: 0.5945 - val_loss: 0.6816 - val_binary_accuracy: 0.6250 - val_auc: 0.6828
# Epoch 2/20
# 62/62 [==============================] - 7s 121ms/step - loss: 0.6818 - binary_accuracy: 0.6323 - auc: 0.6601 - val_loss: 0.6730 - val_binary_accuracy: 0.6540 - val_auc: 0.7035
# Epoch 3/20
# 62/62 [==============================] - 8s 125ms/step - loss: 0.6723 - binary_accuracy: 0.6556 - auc: 0.6962 - val_loss: 0.6617 - val_binary_accuracy: 0.6808 - val_auc: 0.7312
# Epoch 4/20
# 62/62 [==============================] - 8s 125ms/step - loss: 0.6605 - binary_accuracy: 0.6765 - auc: 0.7298 - val_loss: 0.6481 - val_binary_accuracy: 0.7009 - val_auc: 0.7707
# Epoch 5/20
# 62/62 [==============================] - 8s 126ms/step - loss: 0.6486 - binary_accuracy: 0.6857 - auc: 0.7517 - val_loss: 0.6363 - val_binary_accuracy: 0.7143 - val_auc: 0.7851
# Epoch 6/20
# 62/62 [==============================] - 8s 125ms/step - loss: 0.6385 - binary_accuracy: 0.6946 - auc: 0.7620 - val_loss: 0.6262 - val_binary_accuracy: 0.7188 - val_auc: 0.7929
# Epoch 7/20
# 62/62 [==============================] - 8s 129ms/step - loss: 0.6299 - binary_accuracy: 0.7014 - auc: 0.7687 - val_loss: 0.6172 - val_binary_accuracy: 0.7232 - val_auc: 0.7963
# Epoch 8/20
# 62/62 [==============================] - 8s 128ms/step - loss: 0.6221 - binary_accuracy: 0.7079 - auc: 0.7713 - val_loss: 0.6088 - val_binary_accuracy: 0.7299 - val_auc: 0.8001
# Epoch 9/20
# 62/62 [==============================] - 8s 126ms/step - loss: 0.6151 - binary_accuracy: 0.7133 - auc: 0.7748 - val_loss: 0.6010 - val_binary_accuracy: 0.7366 - val_auc: 0.7996
# Epoch 10/20
# 62/62 [==============================] - 8s 124ms/step - loss: 0.6088 - binary_accuracy: 0.7161 - auc: 0.7774 - val_loss: 0.5939 - val_binary_accuracy: 0.7366 - val_auc: 0.8021
# Epoch 11/20
# 62/62 [==============================] - 8s 129ms/step - loss: 0.6031 - binary_accuracy: 0.7144 - auc: 0.7785 - val_loss: 0.5874 - val_binary_accuracy: 0.7388 - val_auc: 0.8032
# Epoch 12/20
# 62/62 [==============================] - 8s 129ms/step - loss: 0.5980 - binary_accuracy: 0.7149 - auc: 0.7796 - val_loss: 0.5815 - val_binary_accuracy: 0.7433 - val_auc: 0.8051
# Epoch 13/20
# 62/62 [==============================] - 8s 132ms/step - loss: 0.5935 - binary_accuracy: 0.7172 - auc: 0.7810 - val_loss: 0.5762 - val_binary_accuracy: 0.7388 - val_auc: 0.8063
# Epoch 14/20
# 62/62 [==============================] - 8s 130ms/step - loss: 0.5895 - binary_accuracy: 0.7183 - auc: 0.7826 - val_loss: 0.5714 - val_binary_accuracy: 0.7388 - val_auc: 0.8074
# Epoch 15/20
# 62/62 [==============================] - 8s 132ms/step - loss: 0.5860 - binary_accuracy: 0.7194 - auc: 0.7829 - val_loss: 0.5671 - val_binary_accuracy: 0.7388 - val_auc: 0.8112
# Epoch 16/20
# 62/62 [==============================] - 8s 132ms/step - loss: 0.5828 - binary_accuracy: 0.7207 - auc: 0.7830 - val_loss: 0.5631 - val_binary_accuracy: 0.7433 - val_auc: 0.8117
# Epoch 17/20
# 62/62 [==============================] - 8s 124ms/step - loss: 0.5799 - binary_accuracy: 0.7241 - auc: 0.7845 - val_loss: 0.5596 - val_binary_accuracy: 0.7455 - val_auc: 0.8135
# Epoch 18/20
# 62/62 [==============================] - 8s 127ms/step - loss: 0.5773 - binary_accuracy: 0.7246 - auc: 0.7842 - val_loss: 0.5563 - val_binary_accuracy: 0.7500 - val_auc: 0.8150
# Epoch 19/20
# 62/62 [==============================] - 8s 125ms/step - loss: 0.5750 - binary_accuracy: 0.7248 - auc: 0.7855 - val_loss: 0.5532 - val_binary_accuracy: 0.7522 - val_auc: 0.8165
# Epoch 20/20
# 62/62 [==============================] - 8s 124ms/step - loss: 0.5729 - binary_accuracy: 0.7247 - auc: 0.7853 - val_loss: 0.5504 - val_binary_accuracy: 0.7522 - val_auc: 0.8185
# Epoch 1/20
# 62/62 [==============================] - 9s 133ms/step - loss: 0.7515 - binary_accuracy: 0.3629 - auc: 0.3437 - val_loss: 0.7135 - val_binary_accuracy: 0.4286 - val_auc: 0.4354
# Epoch 2/20
# 62/62 [==============================] - 9s 140ms/step - loss: 0.6932 - binary_accuracy: 0.5268 - auc: 0.5402 - val_loss: 0.6583 - val_binary_accuracy: 0.6830 - val_auc: 0.7182
# Epoch 3/20
# 62/62 [==============================] - 9s 141ms/step - loss: 0.6535 - binary_accuracy: 0.6847 - auc: 0.7209 - val_loss: 0.6297 - val_binary_accuracy: 0.7478 - val_auc: 0.7633
# Epoch 4/20
# 62/62 [==============================] - 9s 139ms/step - loss: 0.6329 - binary_accuracy: 0.7065 - auc: 0.7477 - val_loss: 0.6111 - val_binary_accuracy: 0.7567 - val_auc: 0.7855
# Epoch 5/20
# 62/62 [==============================] - 9s 140ms/step - loss: 0.6204 - binary_accuracy: 0.7165 - auc: 0.7573 - val_loss: 0.5983 - val_binary_accuracy: 0.7634 - val_auc: 0.8002
# Epoch 6/20
# 62/62 [==============================] - 9s 140ms/step - loss: 0.6119 - binary_accuracy: 0.7148 - auc: 0.7620 - val_loss: 0.5891 - val_binary_accuracy: 0.7656 - val_auc: 0.8097
# Epoch 7/20
# 62/62 [==============================] - 9s 141ms/step - loss: 0.6056 - binary_accuracy: 0.7176 - auc: 0.7650 - val_loss: 0.5822 - val_binary_accuracy: 0.7679 - val_auc: 0.8145
# Epoch 8/20
# 62/62 [==============================] - 9s 141ms/step - loss: 0.6007 - binary_accuracy: 0.7200 - auc: 0.7679 - val_loss: 0.5768 - val_binary_accuracy: 0.7656 - val_auc: 0.8177
# Epoch 9/20
# 62/62 [==============================] - 9s 143ms/step - loss: 0.5968 - binary_accuracy: 0.7194 - auc: 0.7699 - val_loss: 0.5723 - val_binary_accuracy: 0.7656 - val_auc: 0.8189
# Epoch 10/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.5935 - binary_accuracy: 0.7200 - auc: 0.7709 - val_loss: 0.5683 - val_binary_accuracy: 0.7634 - val_auc: 0.8198
# Epoch 11/20
# 62/62 [==============================] - 9s 139ms/step - loss: 0.5905 - binary_accuracy: 0.7195 - auc: 0.7722 - val_loss: 0.5647 - val_binary_accuracy: 0.7634 - val_auc: 0.8216
# Epoch 12/20
# 62/62 [==============================] - 9s 139ms/step - loss: 0.5878 - binary_accuracy: 0.7218 - auc: 0.7734 - val_loss: 0.5613 - val_binary_accuracy: 0.7656 - val_auc: 0.8232
# Epoch 13/20
# 62/62 [==============================] - 9s 137ms/step - loss: 0.5853 - binary_accuracy: 0.7208 - auc: 0.7745 - val_loss: 0.5582 - val_binary_accuracy: 0.7679 - val_auc: 0.8229
# Epoch 14/20
# 62/62 [==============================] - 9s 139ms/step - loss: 0.5830 - binary_accuracy: 0.7214 - auc: 0.7757 - val_loss: 0.5553 - val_binary_accuracy: 0.7679 - val_auc: 0.8237
# Epoch 15/20
# 62/62 [==============================] - 8s 137ms/step - loss: 0.5809 - binary_accuracy: 0.7220 - auc: 0.7768 - val_loss: 0.5525 - val_binary_accuracy: 0.7701 - val_auc: 0.8246
# Epoch 16/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.5790 - binary_accuracy: 0.7238 - auc: 0.7773 - val_loss: 0.5499 - val_binary_accuracy: 0.7701 - val_auc: 0.8260
# Epoch 17/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.5772 - binary_accuracy: 0.7244 - auc: 0.7782 - val_loss: 0.5474 - val_binary_accuracy: 0.7701 - val_auc: 0.8273
# Epoch 18/20
# 62/62 [==============================] - 9s 139ms/step - loss: 0.5756 - binary_accuracy: 0.7263 - auc: 0.7790 - val_loss: 0.5451 - val_binary_accuracy: 0.7679 - val_auc: 0.8279
# Epoch 19/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.5741 - binary_accuracy: 0.7264 - auc: 0.7797 - val_loss: 0.5429 - val_binary_accuracy: 0.7656 - val_auc: 0.8283
# Epoch 20/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.5727 - binary_accuracy: 0.7275 - auc: 0.7806 - val_loss: 0.5408 - val_binary_accuracy: 0.7634 - val_auc: 0.8295
# Epoch 1/20
# 62/62 [==============================] - 10s 146ms/step - loss: 0.6777 - binary_accuracy: 0.5684 - auc: 0.6385 - val_loss: 0.6696 - val_binary_accuracy: 0.6094 - val_auc: 0.6783
# Epoch 2/20
# 62/62 [==============================] - 9s 147ms/step - loss: 0.6707 - binary_accuracy: 0.5968 - auc: 0.6662 - val_loss: 0.6608 - val_binary_accuracy: 0.6317 - val_auc: 0.7118
# Epoch 3/20
# 62/62 [==============================] - 9s 147ms/step - loss: 0.6637 - binary_accuracy: 0.6280 - auc: 0.6919 - val_loss: 0.6500 - val_binary_accuracy: 0.6763 - val_auc: 0.7436
# Epoch 4/20
# 62/62 [==============================] - 9s 147ms/step - loss: 0.6559 - binary_accuracy: 0.6442 - auc: 0.7154 - val_loss: 0.6387 - val_binary_accuracy: 0.6964 - val_auc: 0.7725
# Epoch 5/20
# 62/62 [==============================] - 9s 143ms/step - loss: 0.6486 - binary_accuracy: 0.6594 - auc: 0.7293 - val_loss: 0.6289 - val_binary_accuracy: 0.7165 - val_auc: 0.7909
# Epoch 6/20
# 62/62 [==============================] - 9s 146ms/step - loss: 0.6429 - binary_accuracy: 0.6615 - auc: 0.7353 - val_loss: 0.6214 - val_binary_accuracy: 0.7098 - val_auc: 0.8001
# Epoch 7/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.6387 - binary_accuracy: 0.6693 - auc: 0.7360 - val_loss: 0.6156 - val_binary_accuracy: 0.7121 - val_auc: 0.8050
# Epoch 8/20
# 62/62 [==============================] - 9s 143ms/step - loss: 0.6356 - binary_accuracy: 0.6738 - auc: 0.7348 - val_loss: 0.6109 - val_binary_accuracy: 0.7188 - val_auc: 0.8069
# Epoch 9/20
# 62/62 [==============================] - 9s 148ms/step - loss: 0.6330 - binary_accuracy: 0.6736 - auc: 0.7340 - val_loss: 0.6069 - val_binary_accuracy: 0.7165 - val_auc: 0.8076
# Epoch 10/20
# 62/62 [==============================] - 9s 148ms/step - loss: 0.6307 - binary_accuracy: 0.6744 - auc: 0.7331 - val_loss: 0.6033 - val_binary_accuracy: 0.7143 - val_auc: 0.8075
# Epoch 11/20
# 62/62 [==============================] - 9s 146ms/step - loss: 0.6287 - binary_accuracy: 0.6728 - auc: 0.7325 - val_loss: 0.6001 - val_binary_accuracy: 0.7143 - val_auc: 0.8081
# Epoch 12/20
# 62/62 [==============================] - 9s 141ms/step - loss: 0.6269 - binary_accuracy: 0.6707 - auc: 0.7318 - val_loss: 0.5971 - val_binary_accuracy: 0.7165 - val_auc: 0.8084
# Epoch 13/20
# 62/62 [==============================] - 9s 145ms/step - loss: 0.6252 - binary_accuracy: 0.6710 - auc: 0.7319 - val_loss: 0.5944 - val_binary_accuracy: 0.7165 - val_auc: 0.8078
# Epoch 14/20
# 62/62 [==============================] - 9s 141ms/step - loss: 0.6236 - binary_accuracy: 0.6684 - auc: 0.7314 - val_loss: 0.5918 - val_binary_accuracy: 0.7121 - val_auc: 0.8078
# Epoch 15/20
# 62/62 [==============================] - 9s 143ms/step - loss: 0.6221 - binary_accuracy: 0.6701 - auc: 0.7311 - val_loss: 0.5894 - val_binary_accuracy: 0.7076 - val_auc: 0.8080
# Epoch 16/20
# 62/62 [==============================] - 9s 145ms/step - loss: 0.6208 - binary_accuracy: 0.6718 - auc: 0.7311 - val_loss: 0.5871 - val_binary_accuracy: 0.7098 - val_auc: 0.8081
# Epoch 17/20
# 62/62 [==============================] - 9s 143ms/step - loss: 0.6195 - binary_accuracy: 0.6728 - auc: 0.7309 - val_loss: 0.5850 - val_binary_accuracy: 0.7076 - val_auc: 0.8077
# Epoch 18/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.6183 - binary_accuracy: 0.6708 - auc: 0.7308 - val_loss: 0.5829 - val_binary_accuracy: 0.7098 - val_auc: 0.8074
# Epoch 19/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.6172 - binary_accuracy: 0.6715 - auc: 0.7305 - val_loss: 0.5810 - val_binary_accuracy: 0.7121 - val_auc: 0.8076
# Epoch 20/20
# 62/62 [==============================] - 9s 138ms/step - loss: 0.6162 - binary_accuracy: 0.6698 - auc: 0.7308 - val_loss: 0.5792 - val_binary_accuracy: 0.7121 - val_auc: 0.8076
# Epoch 1/20
# 62/62 [==============================] - 9s 133ms/step - loss: 0.6948 - binary_accuracy: 0.4915 - auc: 0.5188 - val_loss: 0.6959 - val_binary_accuracy: 0.4576 - val_auc: 0.5105
# Epoch 2/20
# 62/62 [==============================] - 8s 127ms/step - loss: 0.6895 - binary_accuracy: 0.5144 - auc: 0.5536 - val_loss: 0.6903 - val_binary_accuracy: 0.5112 - val_auc: 0.5484
# Epoch 3/20
# 62/62 [==============================] - 8s 133ms/step - loss: 0.6845 - binary_accuracy: 0.5513 - auc: 0.5860 - val_loss: 0.6843 - val_binary_accuracy: 0.5580 - val_auc: 0.5824
# Epoch 4/20
# 62/62 [==============================] - 8s 130ms/step - loss: 0.6787 - binary_accuracy: 0.5948 - auc: 0.6155 - val_loss: 0.6773 - val_binary_accuracy: 0.5982 - val_auc: 0.6154
# Epoch 5/20
# 62/62 [==============================] - 8s 133ms/step - loss: 0.6720 - binary_accuracy: 0.6237 - auc: 0.6399 - val_loss: 0.6703 - val_binary_accuracy: 0.6540 - val_auc: 0.6355
# Epoch 6/20
# 62/62 [==============================] - 8s 135ms/step - loss: 0.6656 - binary_accuracy: 0.6441 - auc: 0.6571 - val_loss: 0.6641 - val_binary_accuracy: 0.6696 - val_auc: 0.6491
# Epoch 7/20
# 62/62 [==============================] - 8s 137ms/step - loss: 0.6601 - binary_accuracy: 0.6604 - auc: 0.6672 - val_loss: 0.6581 - val_binary_accuracy: 0.6875 - val_auc: 0.6599
# Epoch 8/20
# 62/62 [==============================] - 9s 139ms/step - loss: 0.6549 - binary_accuracy: 0.6685 - auc: 0.6757 - val_loss: 0.6515 - val_binary_accuracy: 0.6897 - val_auc: 0.6719
# Epoch 9/20
# 62/62 [==============================] - 9s 138ms/step - loss: 0.6498 - binary_accuracy: 0.6772 - auc: 0.6843 - val_loss: 0.6450 - val_binary_accuracy: 0.7054 - val_auc: 0.6824
# Epoch 10/20
# 62/62 [==============================] - 9s 143ms/step - loss: 0.6454 - binary_accuracy: 0.6802 - auc: 0.6900 - val_loss: 0.6399 - val_binary_accuracy: 0.6942 - val_auc: 0.6925
# Epoch 11/20
# 62/62 [==============================] - 9s 140ms/step - loss: 0.6422 - binary_accuracy: 0.6754 - auc: 0.6929 - val_loss: 0.6362 - val_binary_accuracy: 0.6853 - val_auc: 0.6970
# Epoch 12/20
# 62/62 [==============================] - 9s 138ms/step - loss: 0.6400 - binary_accuracy: 0.6748 - auc: 0.6949 - val_loss: 0.6335 - val_binary_accuracy: 0.6897 - val_auc: 0.7010
# Epoch 13/20
# 62/62 [==============================] - 9s 140ms/step - loss: 0.6383 - binary_accuracy: 0.6728 - auc: 0.6951 - val_loss: 0.6315 - val_binary_accuracy: 0.6830 - val_auc: 0.7037
# Epoch 14/20
# 62/62 [==============================] - 9s 141ms/step - loss: 0.6369 - binary_accuracy: 0.6724 - auc: 0.6959 - val_loss: 0.6299 - val_binary_accuracy: 0.6808 - val_auc: 0.7043
# Epoch 15/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.6358 - binary_accuracy: 0.6730 - auc: 0.6961 - val_loss: 0.6287 - val_binary_accuracy: 0.6808 - val_auc: 0.7050
# Epoch 16/20
# 62/62 [==============================] - 9s 140ms/step - loss: 0.6349 - binary_accuracy: 0.6719 - auc: 0.6962 - val_loss: 0.6277 - val_binary_accuracy: 0.6853 - val_auc: 0.7048
# Epoch 17/20
# 62/62 [==============================] - 9s 145ms/step - loss: 0.6341 - binary_accuracy: 0.6718 - auc: 0.6958 - val_loss: 0.6269 - val_binary_accuracy: 0.6853 - val_auc: 0.7046
# Epoch 18/20
# 62/62 [==============================] - 9s 145ms/step - loss: 0.6334 - binary_accuracy: 0.6726 - auc: 0.6962 - val_loss: 0.6262 - val_binary_accuracy: 0.6853 - val_auc: 0.7038
# Epoch 19/20
# 62/62 [==============================] - 9s 142ms/step - loss: 0.6328 - binary_accuracy: 0.6729 - auc: 0.6961 - val_loss: 0.6257 - val_binary_accuracy: 0.6830 - val_auc: 0.7041
# Epoch 20/20
# 62/62 [==============================] - 9s 144ms/step - loss: 0.6324 - binary_accuracy: 0.6722 - auc: 0.6958 - val_loss: 0.6253 - val_binary_accuracy: 0.6853 - val_auc: 0.7038
# Epoch 1/20
# 62/62 [==============================] - 1s 7ms/step - loss: 0.8663 - binary_accuracy: 0.3864 - auc: 0.1990 - val_loss: 0.8276 - val_binary_accuracy: 0.3549 - val_auc: 0.1430
# Epoch 2/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8041 - binary_accuracy: 0.3545 - auc: 0.1964 - val_loss: 0.7831 - val_binary_accuracy: 0.3080 - val_auc: 0.1413
# Epoch 3/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7665 - binary_accuracy: 0.3062 - auc: 0.1951 - val_loss: 0.7553 - val_binary_accuracy: 0.2500 - val_auc: 0.1432
# Epoch 4/20
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7424 - binary_accuracy: 0.2587 - auc: 0.1950 - val_loss: 0.7350 - val_binary_accuracy: 0.2165 - val_auc: 0.1422
# Epoch 5/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7252 - binary_accuracy: 0.2722 - auc: 0.1957 - val_loss: 0.7192 - val_binary_accuracy: 0.2612 - val_auc: 0.1441
# Epoch 6/20
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7128 - binary_accuracy: 0.3330 - auc: 0.1973 - val_loss: 0.7088 - val_binary_accuracy: 0.4107 - val_auc: 0.1524
# Epoch 7/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7053 - binary_accuracy: 0.4505 - auc: 0.2027 - val_loss: 0.7041 - val_binary_accuracy: 0.4911 - val_auc: 0.1554
# Epoch 8/20
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7016 - binary_accuracy: 0.5019 - auc: 0.2067 - val_loss: 0.7012 - val_binary_accuracy: 0.4978 - val_auc: 0.1756
# Epoch 9/20
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6991 - binary_accuracy: 0.5035 - auc: 0.2212 - val_loss: 0.6989 - val_binary_accuracy: 0.4978 - val_auc: 0.1798
# Epoch 10/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6971 - binary_accuracy: 0.5035 - auc: 0.2578 - val_loss: 0.6969 - val_binary_accuracy: 0.4978 - val_auc: 0.2156
# Epoch 11/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6914 - binary_accuracy: 0.5035 - auc: 0.4162 - val_loss: 0.6573 - val_binary_accuracy: 0.4978 - val_auc: 0.8203
# Epoch 12/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6557 - binary_accuracy: 0.5035 - auc: 0.7838 - val_loss: 0.6306 - val_binary_accuracy: 0.4978 - val_auc: 0.8364
# Epoch 13/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6380 - binary_accuracy: 0.6150 - auc: 0.7965 - val_loss: 0.6156 - val_binary_accuracy: 0.7031 - val_auc: 0.8365
# Epoch 14/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6267 - binary_accuracy: 0.7017 - auc: 0.7955 - val_loss: 0.6031 - val_binary_accuracy: 0.7277 - val_auc: 0.8339
# Epoch 15/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6172 - binary_accuracy: 0.7098 - auc: 0.7956 - val_loss: 0.5922 - val_binary_accuracy: 0.7433 - val_auc: 0.8366
# Epoch 16/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6089 - binary_accuracy: 0.7167 - auc: 0.7954 - val_loss: 0.5827 - val_binary_accuracy: 0.7500 - val_auc: 0.8345
# Epoch 17/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6018 - binary_accuracy: 0.7214 - auc: 0.7953 - val_loss: 0.5742 - val_binary_accuracy: 0.7545 - val_auc: 0.8350
# Epoch 18/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5957 - binary_accuracy: 0.7221 - auc: 0.7950 - val_loss: 0.5668 - val_binary_accuracy: 0.7589 - val_auc: 0.8360
# Epoch 19/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5903 - binary_accuracy: 0.7251 - auc: 0.7953 - val_loss: 0.5602 - val_binary_accuracy: 0.7634 - val_auc: 0.8353
# Epoch 20/20
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5855 - binary_accuracy: 0.7277 - auc: 0.7954 - val_loss: 0.5543 - val_binary_accuracy: 0.7634 - val_auc: 0.8366

# %%
# Plot the roc curves
fpr_list, tpr_list = [], []

for i, model in enumerate(models):
    y_score = model.predict(val_ds)
    y_true = y_val[:len(y_score)]
    fpr, tpr, _ = roc_curve(y_true, y_score)
    fpr_list.append(fpr)
    tpr_list.append(tpr)

labels = ['1_qubit_depth_6',
          '2_qubit_depth_3',
          '3_qubit_depth_2',
          '6_qubit_depth_1',
          'classical']

for fpr, tpr, label in zip(fpr_list, tpr_list, labels):
  roc_auc = auc(fpr, tpr)
  label += ', AUC={:.4f}'.format(roc_auc)
  plt.plot(tpr, 1 - fpr, linestyle='-', label=label, linewidth=2)

plt.xlabel("Signal Efficiency", fontsize=18, fontweight='bold')
plt.ylabel("Background Rejection", fontsize=18, fontweight='bold')
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.grid(color='gray', linestyle='--', linewidth=1) 
plt.plot([0, 1], [1, 0], linestyle='--', color='black', label='Luck, AUC= 0.5')
plt.legend(loc='best',prop={'size': 8})
